# %% [markdown]
# <h1>Atividade 02 - CCF493</h1>
#
# <h3>Nome: Vítor Luís G. Silva</h3>
# <h3>Matrícula: 3045</h3>

# %%
import sqlite3
import numpy as np
import pandas as pd
import pyarrow.parquet as pq

# %%
# Leitura do arquivo csv
data_csv = pd.read_csv('./data/titanic_train.csv')

# Exibição do arquivo csv
data_csv.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
# Leitura do arquivo json
data_json = pd.read_json('./data/champion_info.json')

# Exibição do arquivo json
data_json.head()
# Out:
#          type version                                               data
# 1    champion  7.17.2  {'title': 'the Dark Child', 'id': 1, 'key': 'A...
# 10   champion  7.17.2  {'title': 'The Judicator', 'id': 10, 'key': 'K...
# 101  champion  7.17.2  {'title': 'the Magus Ascendant', 'id': 101, 'k...
# 102  champion  7.17.2  {'title': 'the Half-Dragon', 'id': 102, 'key':...
# 103  champion  7.17.2  {'title': 'the Nine-Tailed Fox', 'id': 103, 'k...

# %%
# Leitura do arquivo json
data_json = pd.read_json('./data/iris.json')

# Exibição do arquivo json
data_json.head()
# Out:
#    sepalLength  sepalWidth  petalLength  petalWidth species
# 0          5.1         3.5          1.4         0.2  setosa
# 1          4.9         3.0          1.4         0.2  setosa
# 2          4.7         3.2          1.3         0.2  setosa
# 3          4.6         3.1          1.5         0.2  setosa
# 4          5.0         3.6          1.4         0.2  setosa

# %%
# Leitura do arquivo xls
file = r'./data/pib_municipios.xls'
data_xls = pd.read_excel(file)

# Exibição do arquivo xls
data_xls.head()
# Out:
#     Ano  Código da Grande Região Nome da Grande Região  \
# 0  2010                        1                 Norte
# 1  2010                        1                 Norte
# 2  2010                        1                 Norte
# 3  2010                        1                 Norte
# 4  2010                        1                 Norte
#
#    Código da Unidade da Federação Sigla da Unidade da Federação  \
# 0                              11                            RO
# 1                              11                            RO
# 2                              11                            RO
# 3                              11                            RO
# 4                              11                            RO
#
#   Nome da Unidade da Federação  Código do Município      Nome do Município  \
# 0                     Rondônia              1100015  Alta Floresta D'Oeste
# 1                     Rondônia              1100023              Ariquemes
# ...

# %%
# Leitura do arquivo parquet
data_parquet = pq.read_table(source='./data/user_tracking.parquet').to_pandas()

# Exibição do arquivo parquet
data_parquet.head()
# Out:
#   installation_number external_identifier               handset       os  \
# 0             7206043                          samsung:SM-J700M  ANDROID
# 1             6219664           367738313  LENOVO:Lenovo K33b36     None
# 2             6485586                          samsung:SM-G928G     None
# 3             7050958           108659666      samsung:SM-G930F     None
# 4             7131516           108027625       asus:ASUS_X013D     None
#
#   os_version         host_app_package host_app_version lib_version  \
# 0      6.0.1  com.fiat.uconnectmobile            5.4.3      2.2.18
# 1      6.0.1     com.pontomobi.smiles             None    2.2.17.2
# 2        7.0     com.pontomobi.smiles             None    2.2.17.2
# 3        7.0     com.pontomobi.smiles             None      2.2.17
# 4      5.1.1     com.pontomobi.smiles             None    2.2.17.2
#
#   config_version                        advertising_id  ...  \
# ...

# %%
# Leitura da API do IBGE
data_api = pd.read_json('https://servicodados.ibge.gov.br/api/v1/localidades/estados/MG/municipios')

# Exibição da API do IBGE
data_api.head()
# Out:
#         id                 nome  \
# 0  3100104  Abadia dos Dourados
# 1  3100203               Abaeté
# 2  3100302           Abre Campo
# 3  3100401              Acaiaca
# 4  3100500              Açucena
#
#                                         microrregiao  \
# 0  {'id': 31019, 'nome': 'Patrocínio', 'mesorregi...
# 1  {'id': 31024, 'nome': 'Três Marias', 'mesorreg...
# 2  {'id': 31061, 'nome': 'Manhuaçu', 'mesorregiao...
# 3  {'id': 31060, 'nome': 'Ponte Nova', 'mesorregi...
# 4  {'id': 31039, 'nome': 'Ipatinga', 'mesorregiao...
#
#                                      regiao-imediata
# 0  {'id': 310061, 'nome': 'Monte Carmelo', 'regia...
# 1  {'id': 310070, 'nome': 'Abaeté', 'regiao-inter...
# 2  {'id': 310028, 'nome': 'Manhuaçu', 'regiao-int...
# 3  {'id': 310030, 'nome': 'Ponte Nova', 'regiao-i...
# 4  {'id': 310024, 'nome': 'Ipatinga', 'regiao-int...

# %%
connection = sqlite3.connect('./data/database.db')

f = open('./data/cliente_cidade.sql', 'r')
script = f.read()

connection.executescript(script)

data_sql = pd.read_sql(sql='SELECT * from Cliente', con=connection)

data_sql.head()
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# <ipython-input-8-cb964107c18e> in <module>
#       4 script = f.read()
#       5
# ----> 6 connection.executescript(script)
#       7
#       8 data_sql = pd.read_sql(sql='SELECT * from Cliente', con=connection)
#
# OperationalError: near "ENGINE": syntax error
